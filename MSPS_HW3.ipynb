# %% [markdown]
# # Критерии согласия, проверка нормальности, бутстреп

# %% [markdown]
# ## Задача 2

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd

# %matplotlib inline

# %%
data = pd.read_csv('slump_test.data')
sample = np.array(data["Compressive Strength (28-day)(Mpa)"])
sample.shape
# Out:
# (103,)

# %%
plt.figure(figsize = (10, 7))
plt.hist(sample, bins = 20, alpha = 0.5)
# Out:
# (array([ 4.,  0.,  0.,  1.,  6.,  9., 10., 12., 12.,  9.,  8., 11.,  5.,
#          6.,  1.,  5.,  1.,  2.,  0.,  1.]),
#  array([17.19 , 19.257, 21.324, 23.391, 25.458, 27.525, 29.592, 31.659,
#         33.726, 35.793, 37.86 , 39.927, 41.994, 44.061, 46.128, 48.195,
#         50.262, 52.329, 54.396, 56.463, 58.53 ]),
#  <a list of 20 Patch objects>)

# %%
plt.figure(figsize = (10, 7))
stats.probplot(sample, plot=plt);

# %% [markdown]
# Про хвосты распределения нельзя сказать, легче они или тяжелее, чем у нормального, поэтому можно сказать, что распределение близко к нормальному.

# %%
stats.normaltest(sample)
# Out:
# NormaltestResult(statistic=1.050156761823201, pvalue=0.5915089995351763)

# %%
stats.normaltest(norm_sample)
# Out:
# NormaltestResult(statistic=1.4622895950785897, pvalue=0.481357617529376)

# %%
stats.shapiro(sample)
# Out:
# (0.9879489541053772, 0.48257023096084595)

# %%
stats.shapiro(norm_sample)
# Out:
# (0.9881889820098877, 0.5004028081893921)

# %% [markdown]
# Таким образом, исходя из QQ-plot и теста Шапиро-Уилка, мы имеем нормальное распределение.
